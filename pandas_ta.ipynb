# %%
import pandas_ta as ta
import pandas as pd

# %%
df = pd.DataFrame()
df = df.ta.ticker("AAPL").tz_localize(None)

# %%
rsi = df.ta.rsi(append=True)
macd = df.ta.macd(append=True)
df.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  59144500
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  42841800
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  46792900
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  49128400
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  40444700
#
#             Dividends  Stock Splits     RSI_14  MACD_12_26_9  MACDh_12_26_9  \
# Date
# 2024-01-08        0.0           0.0  41.372656     -1.473934      -1.751960
# 2024-01-09        0.0           0.0  40.633724     -1.600562      -1.502869
# 2024-01-10        0.0           0.0  43.357437     -1.597770      -1.200062
# 2024-01-11        0.0           0.0  42.166900     -1.625238      -0.982024
# 2024-01-12        0.0           0.0  43.092439     -1.601913      -0.766959
#
#             MACDs_12_26_9
# Date
# 2024-01-08       0.278025
# 2024-01-09      -0.097692
# 2024-01-10      -0.397708
# 2024-01-11      -0.643214
# 2024-01-12      -0.834954
