# %%
import pandas_ta as ta
import pandas as pd

# %%
df = pd.DataFrame()
df = df.ta.ticker("AAPL").tz_localize(None)

# %%
rsi = df.ta.rsi(append=True)
macd = df.ta.macd(append=True)
df.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2024-01-19  189.330002  191.949997  188.820007  191.559998  68741000
# 2024-01-22  192.300003  195.330002  192.259995  193.889999  60133900
# 2024-01-23  195.020004  195.750000  193.830002  195.179993  42355600
# 2024-01-24  195.419998  196.380005  194.339996  194.500000  53631300
# 2024-01-25  195.220001  196.270004  193.110001  194.169998  54730800
#
#             Dividends  Stock Splits     RSI_14  MACD_12_26_9  MACDh_12_26_9  \
# Date
# 2024-01-19        0.0           0.0  56.967975     -1.019515       0.199808
# 2024-01-22        0.0           0.0  60.698088     -0.402178       0.653717
# 2024-01-23        0.0           0.0  62.629499      0.188980       0.995900
# 2024-01-24        0.0           0.0  60.929723      0.595740       1.122128
# 2024-01-25        0.0           0.0  60.077561      0.881312       1.126160
#
#             MACDs_12_26_9
# Date
# 2024-01-19      -1.219324
# 2024-01-22      -1.055894
# 2024-01-23      -0.806919
# 2024-01-24      -0.526388
# 2024-01-25      -0.244848
