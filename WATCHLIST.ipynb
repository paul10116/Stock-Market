# %%
from components.watchlistPosition import pair

# %%
pair("CSCO", "MRVL");

# %%
pair("ACAD", "VRE");

# %%
pair("CENX", "ESTE");

# %%
pair("AEO", "TTMI");

# %%
pair("NYCB", "PRTS");

# %%
pair("BAC", "CNP");

# %%
pair("CGNX", "AES");

# %%
pair("CG", "AES");

# %%
pair("CG", "CMC");

# %%
pair("CORT", "AES");
